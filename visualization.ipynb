# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("file.csv")

# %%
theta0 = np.unique(np.array(df['theta0']))
a = np.unique(np.array(df['a']))
loss = np.array(df['loss'])

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
X, Y = np.meshgrid(theta0, a)
Z = loss.reshape(80, 100)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('theta0')
ax.set_ylabel('a')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 0.5, 'a')

# %%
X[1].shape
# Out:
# (100,)

# %%
Y[1].shape
# Out:
# (100,)

# %%
Z[1].shape
# Out:
# (100,)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
fig.plot(X[1], Z[1])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d60a794aeee2> in <module>
#       1 fig = plt.figure()
# ----> 2 fig.plot(X[1], Z[1])
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
plt.plot(Y[։1], Z[1])
# Out:
#   File "<ipython-input-43-9e47fa95f22c>", line 1
#     plt.plot(Y[։1], Z[1])
#                 ^
# SyntaxError: invalid character in identifier

# %%
len(Y)
# Out:
# 80

# %%
Y_ = []
for i in range(len(Y)):
    Y_.append(Y[i][0])

# %%
plt.plot(Y_, Z[0])
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e77b3f77f780> in <module>
# ----> 1 plt.plot(Y_, Z[0])
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1660         """
#    1661         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663         for line in lines:
#    1664             self.add_line(line)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     502
#     503         if x.shape[0] != y.shape[0]:
# --> 504             raise ValueError(f"x and y must have same first dimension, but "
#     505                              f"have shapes {x.shape} and {y.shape}")
#     506         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (80,) and (100,)
